# %%
from tqdm import tqdm
import os

# %%
path = "/aloy/scratch/acomajuncosa/Ersilia/gcadda4tb-enamine-real-screening"
for file in tqdm(sorted(os.listdir(path))):
    lines = open(os.path.join(path, file)).readlines()
    error_lines = [i for i in lines if "error" in i.lower() or "warning" in i.lower()]
    if len(error_lines) > 0:
        print(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 path = "/aloy/scratch/acomajuncosa/Ersilia/gcadda4tb-enamine-real-screening"
# ----> 2 for file in tqdm(sorted(os.listdir(path))):
#       3     lines = open(os.path.join(path, file)).readlines()
#       4     error_lines = [i for i in lines if "error" in i.lower() or "warning" in i.lower()]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/aloy/scratch/acomajuncosa/Ersilia/gcadda4tb-enamine-real-screening'
