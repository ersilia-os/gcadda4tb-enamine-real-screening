# %%
from tqdm import tqdm
import os

# %%
path = "/aloy/scratch/acomajuncosa/Ersilia/gardp-kpneumoniae-enamine-real-screening"
for file in tqdm(sorted(os.listdir(path))):
    lines = open(os.path.join(path, file)).readlines()
    error_lines = [i for i in lines if "error" in i.lower() or "warning" in i.lower()]
    if len(error_lines) > 0:
        print(file)
# Out:
#   0%|          | 0/994 [00:00<?, ?it/s]
# 100%|██████████| 994/994 [02:55<00:00,  5.67it/s]
